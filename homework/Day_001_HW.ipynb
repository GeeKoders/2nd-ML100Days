# %% [markdown]
# ### 作業1 :
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# #### 1. 你選的這組資料為何重要
#
# 資料的選擇主要是看病人是不是患有心臟病，健康是人一生中最重要的財富，如果有存款簿上有很多個0，前面沒有1(健康)，一切均是枉然。
# 另外，病人是否患有心臟病或是有心臟病程度如何，也是可以透過資料去評估，去挖掘潛在的心臟病病患。
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#  資料來源: The Cleveland database
#
#  https://www.kaggle.com/ronitf/heart-disease-uci
#
#  #### 3. 蒐集而來的資料型態為何
#
#  結構化資料：數值、類別資料
#  #### 4. 這組資料想解決的問題如何評估
#
# 評估是否存在心臟病，數值從0(無存在)到4，可以利用二元分類法(binary classification)去評估

# %% [markdown]
# ### 作業2 :
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 我這裡定義提升業績也就是提升載客率或是減少空車率
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 資料來源是來自於乘車歷史數據資料中。
#
# 這些資料會影響業績的包含當天的時空情境（星期、時段和區域等）和外部事件（天氣、節慶、活動等)。
#
# 資料蒐集可以透過手機叫車APP
#
# #### 3. 蒐集而來的資料型態為何
#
# 結構化資料：數值、類別資料
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 利用統計學和機器學習的演算法，對不同區域的各個時段乘客叫車的需求，建立需求量預測模型來評估。
#
# 看不同的時空情境或是外部事件對載客率和空車率的影響。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
     計算 mse
    Args:
        - y: 實際值
        - y_hat: 預測值
    Return:
        - mse: MSE
    
    """
    square_error = (y - y_hat) ** 2
    mse = MSE = sum(square_error) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    absolute_error = abs(y - y_hat)
    mae = MAE = sum(absolute_error) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 194.888
# The Mean absolute error is 10.321
