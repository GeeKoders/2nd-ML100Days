# %%
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# 此函數會幫我們把多張影像畫成一張多宮格圖
def img_combine(img, ncols=8, size=1, path=False):
    from math import ceil
    import matplotlib.pyplot as plt
    import numpy as np
    nimg = len(img)
    print('nimg %i' %(nimg))
    nrows = int(ceil(nimg/ncols))
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True, figsize=(ncols*size,nrows*size))
    if nrows == 0:
        return
    elif ncols == 1:
        for r, ax in zip(np.arange(nrows), axes):
            print('r:%i' %r)
            print('ax:%i' %ax)
            nth=r
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                
            ax.set_axis_off()
    elif nrows == 1:
        for c, ax in zip(np.arange(ncols), axes):
            nth=c
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
            ax.set_axis_off()
    else:
        for r, row in zip(np.arange(nrows), axes):
            for c, ax in zip(np.arange(ncols), row):
                print('r:%i' %r)
                print('row:%row' %row)
                print('c:%i' %c)
                print('ax:' ,ax)
                nth=r*ncols+c
                if nth < nimg:
                    ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                ax.set_axis_off()
    plt.show()

# %%
# 讀取 Cifar-10 資料集
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# 取前 32 張圖片做視覺化
images = x_train[:32]
img_combine(images)
# Out:
# nimg 32
# r:0
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A64FE80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A644978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A69D898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6CBB00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6FADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A735080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A764320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A792588>],
#       dtype=object)ow
# c:0
# ax: AxesSubplot(0.125,0.71587;0.0824468x0.16413)
# r:0
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A64FE80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A644978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A69D898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6CBB00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6FADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A735080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A764320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A792588>],
#       dtype=object)ow
# c:1
# ax: AxesSubplot(0.223936,0.71587;0.0824468x0.16413)
# r:0
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A64FE80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A644978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A69D898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6CBB00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6FADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A735080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A764320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A792588>],
#       dtype=object)ow
# c:2
# ax: AxesSubplot(0.322872,0.71587;0.0824468x0.16413)
# r:0
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A64FE80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A644978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A69D898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6CBB00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6FADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A735080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A764320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A792588>],
#       dtype=object)ow
# c:3
# ax: AxesSubplot(0.421809,0.71587;0.0824468x0.16413)
# r:0
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A64FE80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A644978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A69D898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6CBB00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6FADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A735080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A764320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A792588>],
#       dtype=object)ow
# c:4
# ax: AxesSubplot(0.520745,0.71587;0.0824468x0.16413)
# r:0
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A64FE80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A644978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A69D898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6CBB00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6FADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A735080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A764320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A792588>],
#       dtype=object)ow
# c:5
# ax: AxesSubplot(0.619681,0.71587;0.0824468x0.16413)
# r:0
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A64FE80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A644978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A69D898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6CBB00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6FADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A735080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A764320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A792588>],
#       dtype=object)ow
# c:6
# ax: AxesSubplot(0.718617,0.71587;0.0824468x0.16413)
# r:0
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A64FE80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A644978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A69D898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6CBB00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A6FADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A735080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A764320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A792588>],
#       dtype=object)ow
# c:7
# ax: AxesSubplot(0.817553,0.71587;0.0824468x0.16413)
# r:1
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7C2860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7F5B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A82ADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A868080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A89C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A8CD588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A901828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A935AC8>],
#       dtype=object)ow
# c:0
# ax: AxesSubplot(0.125,0.518913;0.0824468x0.16413)
# r:1
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7C2860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7F5B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A82ADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A868080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A89C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A8CD588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A901828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A935AC8>],
#       dtype=object)ow
# c:1
# ax: AxesSubplot(0.223936,0.518913;0.0824468x0.16413)
# r:1
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7C2860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7F5B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A82ADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A868080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A89C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A8CD588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A901828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A935AC8>],
#       dtype=object)ow
# c:2
# ax: AxesSubplot(0.322872,0.518913;0.0824468x0.16413)
# r:1
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7C2860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7F5B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A82ADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A868080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A89C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A8CD588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A901828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A935AC8>],
#       dtype=object)ow
# c:3
# ax: AxesSubplot(0.421809,0.518913;0.0824468x0.16413)
# r:1
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7C2860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7F5B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A82ADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A868080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A89C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A8CD588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A901828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A935AC8>],
#       dtype=object)ow
# c:4
# ax: AxesSubplot(0.520745,0.518913;0.0824468x0.16413)
# r:1
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7C2860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7F5B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A82ADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A868080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A89C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A8CD588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A901828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A935AC8>],
#       dtype=object)ow
# c:5
# ax: AxesSubplot(0.619681,0.518913;0.0824468x0.16413)
# r:1
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7C2860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7F5B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A82ADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A868080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A89C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A8CD588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A901828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A935AC8>],
#       dtype=object)ow
# c:6
# ax: AxesSubplot(0.718617,0.518913;0.0824468x0.16413)
# r:1
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7C2860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A7F5B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A82ADA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A868080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A89C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A8CD588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A901828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A935AC8>],
#       dtype=object)ow
# c:7
# ax: AxesSubplot(0.817553,0.518913;0.0824468x0.16413)
# r:2
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A968D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9A8048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9DB2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA0D588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA3F828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA73AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AAA6D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F1A20>],
#       dtype=object)ow
# c:0
# ax: AxesSubplot(0.125,0.321957;0.0824468x0.16413)
# r:2
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A968D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9A8048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9DB2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA0D588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA3F828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA73AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AAA6D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F1A20>],
#       dtype=object)ow
# c:1
# ax: AxesSubplot(0.223936,0.321957;0.0824468x0.16413)
# r:2
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A968D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9A8048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9DB2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA0D588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA3F828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA73AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AAA6D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F1A20>],
#       dtype=object)ow
# c:2
# ax: AxesSubplot(0.322872,0.321957;0.0824468x0.16413)
# r:2
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A968D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9A8048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9DB2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA0D588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA3F828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA73AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AAA6D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F1A20>],
#       dtype=object)ow
# c:3
# ax: AxesSubplot(0.421809,0.321957;0.0824468x0.16413)
# r:2
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A968D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9A8048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9DB2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA0D588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA3F828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA73AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AAA6D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F1A20>],
#       dtype=object)ow
# c:4
# ax: AxesSubplot(0.520745,0.321957;0.0824468x0.16413)
# r:2
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A968D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9A8048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9DB2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA0D588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA3F828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA73AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AAA6D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F1A20>],
#       dtype=object)ow
# c:5
# ax: AxesSubplot(0.619681,0.321957;0.0824468x0.16413)
# r:2
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A968D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9A8048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9DB2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA0D588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA3F828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA73AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AAA6D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F1A20>],
#       dtype=object)ow
# c:6
# ax: AxesSubplot(0.718617,0.321957;0.0824468x0.16413)
# r:2
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A968D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9A8048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4A9DB2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA0D588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA3F828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AA73AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4AAA6D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F1A20>],
#       dtype=object)ow
# c:7
# ax: AxesSubplot(0.817553,0.321957;0.0824468x0.16413)
# r:3
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F7DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486E0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488B8C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4888BF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F48324828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F482DA7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4889BBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488F3080>],
#       dtype=object)ow
# c:0
# ax: AxesSubplot(0.125,0.125;0.0824468x0.16413)
# r:3
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F7DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486E0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488B8C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4888BF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F48324828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F482DA7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4889BBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488F3080>],
#       dtype=object)ow
# c:1
# ax: AxesSubplot(0.223936,0.125;0.0824468x0.16413)
# r:3
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F7DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486E0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488B8C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4888BF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F48324828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F482DA7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4889BBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488F3080>],
#       dtype=object)ow
# c:2
# ax: AxesSubplot(0.322872,0.125;0.0824468x0.16413)
# r:3
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F7DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486E0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488B8C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4888BF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F48324828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F482DA7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4889BBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488F3080>],
#       dtype=object)ow
# c:3
# ax: AxesSubplot(0.421809,0.125;0.0824468x0.16413)
# r:3
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F7DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486E0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488B8C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4888BF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F48324828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F482DA7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4889BBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488F3080>],
#       dtype=object)ow
# c:4
# ax: AxesSubplot(0.520745,0.125;0.0824468x0.16413)
# r:3
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F7DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486E0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488B8C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4888BF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F48324828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F482DA7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4889BBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488F3080>],
#       dtype=object)ow
# c:5
# ax: AxesSubplot(0.619681,0.125;0.0824468x0.16413)
# r:3
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F7DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486E0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488B8C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4888BF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F48324828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F482DA7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4889BBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488F3080>],
#       dtype=object)ow
# c:6
# ax: AxesSubplot(0.718617,0.125;0.0824468x0.16413)
# r:3
# row:array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486F7DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F486E0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488B8C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4888BF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F48324828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F482DA7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F4889BBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016F488F3080>],
#       dtype=object)ow
# c:7
# ax: AxesSubplot(0.817553,0.125;0.0824468x0.16413)

# %%
# 建立 ImageDataGenerator，並指定我們要做資料增強的數值範圍
data_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# %%
# 注意！！ ImageDataGenerator 是一個 Generator (生成器)! 對 Generator 不熟悉的同學請回到 Day098 做複習。
# 使用 .flow 後，就會對我們的影像進行增強，再 call next 取出 generator 的圖像。(shuffle=False 因為我們希望圖像的順序不要改變，方便觀察。實際訓練時預設是 shuffle=True) 
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int")) # 注意在訓練時神經網路時，圖像資料必須要是 float32，但在做視覺化時要轉為 int 才能順利畫圖。所以為了畫圖才把資料轉為 int

# %%
# 因為隨機性的關係，所以一樣的圖像再經過一次 generator 後的結果不一定相同
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int"))

# %% [markdown]
# ## 作業

# %% [markdown]
# 請使用 ImageDataGenerator 來進行 Cifar-10 資料集的訓練，並觀察不同的圖像增強方法是否會顯著影響訓練結果

# %%
data_generator = ImageDataGenerator(
    featurewise_center=True,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False)

# %%
# 注意！！ ImageDataGenerator 是一個 Generator (生成器)! 對 Generator 不熟悉的同學請回到 Day098 做複習。
# 使用 .flow 後，就會對我們的影像進行增強，再 call next 取出 generator 的圖像。(shuffle=False 因為我們希望圖像的順序不要改變，方便觀察。實際訓練時預設是 shuffle=True) 
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int")) # 注意在訓練時神經網路時，圖像資料必須要是 float32，但在做視覺化時要轉為 int 才能順利畫圖。所以為了畫圖才把資料轉為 int
